# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
xTest = np.genfromtxt("data/X_test.txt", delimiter = None, skip_header=1)
xTrain = np.genfromtxt("data/X_train.txt", delimiter = None, skip_header=1, encoding='ISO-8859-1')
yTrain = np.genfromtxt("data/Y_train.txt", delimiter = None, skip_header=1)

# %%
yTrainDist = yTrain[:, 1]
yTrainZ = yTrain[:, 0]

# %% [markdown]
# **Control Variables**

# %%
f, ax = plt.subplots(1,2, figsize=[20,8])

ax[0].scatter(xTrain[:,1], xTrain[:,2], c=yTrainDist)
ax[1].scatter(xTrain[:,1], xTrain[:,3], c=yTrainDist)

# %% [markdown]
# **Liquidity Ratios**

# %%
f, ax = plt.subplots(3,2, figsize=[20,12])

ax[0][0].scatter(xTrain[:,1], xTrain[:,4], c=yTrainDist)
ax[0][0].set_ylim(0,22) #to ignore outlier
ax[0][1].scatter(xTrain[:,1], xTrain[:,5], c=yTrainDist)
ax[0][1].set_ylim(0,22) #to ignore outlier
ax[1][0].scatter(xTrain[:,1], xTrain[:,6], c=yTrainDist)
ax[1][0].set_ylim(0,15) #to ignore outlier
ax[1][1].scatter(xTrain[:,1], xTrain[:,7], c=yTrainDist)
ax[2][0].scatter(xTrain[:,1], xTrain[:,8], c=yTrainDist)
ax[2][1].scatter(xTrain[:,1], xTrain[:,9], c=yTrainDist)

# %% [markdown]
# **Profitability Ratios**

# %%
f, ax = plt.subplots(5,2, figsize=[20,12])

ax[0][0].scatter(xTrain[:,1], xTrain[:,10], c=yTrainDist)
ax[0][1].scatter(xTrain[:,1], xTrain[:,11], c=yTrainDist)
ax[1][0].scatter(xTrain[:,1], xTrain[:,12], c=yTrainDist)
ax[1][1].scatter(xTrain[:,1], xTrain[:,13], c=yTrainDist)
ax[2][0].scatter(xTrain[:,1], xTrain[:,14], c=yTrainDist)
ax[2][1].scatter(xTrain[:,1], xTrain[:,15], c=yTrainDist)
ax[3][0].scatter(xTrain[:,1], xTrain[:,16], c=yTrainDist)
ax[3][1].scatter(xTrain[:,1], xTrain[:,17], c=yTrainDist)
ax[4][0].scatter(xTrain[:,1], xTrain[:,18], c=yTrainDist)
ax[4][1].scatter(xTrain[:,1], xTrain[:,19], c=yTrainDist)

# %% [markdown]
# **Capital Structure**

# %%
f, ax = plt.subplots(3,1, figsize=[20,12])

ax[0].scatter(xTrain[:,1], xTrain[:,20], c=yTrainDist)
ax[1].scatter(xTrain[:,1], xTrain[:,21], c=yTrainDist)
ax[2].scatter(xTrain[:,1], xTrain[:,22], c=yTrainDist)

# %% [markdown]
# **Working Captial Efficiency**

# %%
f, ax = plt.subplots(2,2, figsize=[20,12])

ax[0][0].scatter(xTrain[:,1], xTrain[:,23], c=yTrainDist)
ax[0][1].scatter(xTrain[:,1], xTrain[:,24], c=yTrainDist)
ax[1][0].scatter(xTrain[:,1], xTrain[:,25], c=yTrainDist)
ax[1][1].scatter(xTrain[:,1], xTrain[:,26], c=yTrainDist)

# %% [markdown]
# **Debt Management Ratios**

# %%
f, ax = plt.subplots(3,1, figsize=[20,12])

ax[0].scatter(xTrain[:,1], xTrain[:,27], c=yTrainDist)
ax[1].scatter(xTrain[:,1], xTrain[:,28], c=yTrainDist)
ax[2].scatter(xTrain[:,1], xTrain[:,29], c=yTrainDist)

# %% [markdown]
# **Asset Management Ratios**

# %%
f, ax = plt.subplots(2,2, figsize=[20,12])

ax[0][0].scatter(xTrain[:,1], xTrain[:,30], c=yTrainDist)
ax[0][1].scatter(xTrain[:,1], xTrain[:,31], c=yTrainDist)
ax[1][0].scatter(xTrain[:,1], xTrain[:,32], c=yTrainDist)
ax[1][1].scatter(xTrain[:,1], xTrain[:,33], c=yTrainDist)

# %% [markdown]
# **Other**

# %%
f, ax = plt.subplots(1,1, figsize=[20,12])

ax.scatter(xTrain[:,1], xTrain[:,34], c=yTrainDist)
ax.set_ylim(0,500)
# Out:
# (0, 500)
