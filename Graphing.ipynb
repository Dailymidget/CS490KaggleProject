# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
xTest = np.genfromtxt("data/X_test.txt", delimiter = None, skip_header=1)
xTrain = np.genfromtxt("data/X_train.txt", delimiter = None, skip_header=1, encoding='ISO-8859-1')
yTrain = np.genfromtxt("data/Y_train.txt", delimiter = None, skip_header=1)

# %%
yTrainDist = yTrain[:, 1]
yTrainZ = yTrain[:, 0]

xTrainFirsts = xTrain[:,[1,2,3, 4, 10, 20, 23, 27,30]]
xTestFirsts = xTest[:,[1,2,3, 4, 10, 20, 23, 27,30]]

# %%
f, ax = plt.subplots(1,8, figsize=[20,8])

ax[0].scatter(xTrainFirsts[:,0], xTrainFirsts[:,1], c=yTrainDist)
ax[1].scatter(xTrainFirsts[:,0], xTrainFirsts[:,2], c=yTrainDist)
ax[2].scatter(xTrainFirsts[:,0], xTrainFirsts[:,3], c=yTrainDist)
ax[3].scatter(xTrainFirsts[:,0], xTrainFirsts[:,4], c=yTrainDist)
ax[4].scatter(xTrainFirsts[:,0], xTrainFirsts[:,5], c=yTrainDist)
ax[5].scatter(xTrainFirsts[:,0], xTrainFirsts[:,6], c=yTrainDist)
ax[6].scatter(xTrainFirsts[:,0], xTrainFirsts[:,7], c=yTrainDist)
ax[7].scatter(xTrainFirsts[:,0], xTrainFirsts[:,8], c=yTrainDist)
